# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import os

# %%
# --- Quantum Vision Block (simplified example) ---
class QuantumVisionBlock(layers.Layer):
    def __init__(self, filters):
        super(QuantumVisionBlock, self).__init__()
        self.conv1 = layers.Conv2D(filters, kernel_size=3, padding='same', activation='relu')
        self.conv2 = layers.Conv2D(filters, kernel_size=3, padding='same', activation='relu')
        self.pool = layers.MaxPooling2D()

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.conv2(x)
        x = self.pool(x)
        return x

# %%
# --- Build model with QV block ---
def build_qv_model(input_shape=(150, 150, 3), num_classes=6):
    inputs = layers.Input(shape=input_shape)
    
    x = QuantumVisionBlock(32)(inputs)
    x = QuantumVisionBlock(64)(x)
    
    x = layers.Flatten()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# %%
# --- Dataset parameters ---
batch_size = 32
img_size = (150, 150)
train_dir = "archive/train"  # Update with your path
test_dir = "archive/test"    # Update with your path

# --- Load datasets ---
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    batch_size=batch_size,
    image_size=img_size,
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    shuffle=False,
    batch_size=batch_size,
    image_size=img_size,
)
# Out:
# Found 14034 files belonging to 6 classes.
# Found 3000 files belonging to 6 classes.

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# --- Build and compile model ---
model = build_qv_model(input_shape=img_size + (3,), num_classes=6)
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\verti\anaconda3\lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 150, 150, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ quantum_vision_block                 │ (None, 75, 75, 32)          │          10,144 │
# │ (QuantumVisionBlock)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
# --- Train the model ---
epochs = 15
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=epochs
)
# Out:
# Epoch 1/15
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 421s 949ms/step - accuracy: 0.3878 - loss: 35.1664 - val_accuracy: 0.6093 - val_loss: 1.0071
# Epoch 2/15
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 415s 943ms/step - accuracy: 0.6049 - loss: 1.0243 - val_accuracy: 0.6517 - val_loss: 0.9140
# Epoch 3/15
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 433s 984ms/step - accuracy: 0.6583 - loss: 0.8850 - val_accuracy: 0.6940 - val_loss: 0.8036
# Epoch 4/15
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 423s 961ms/step - accuracy: 0.7065 - loss: 0.7695 - val_accuracy: 0.6643 - val_loss: 0.9018
# Epoch 5/15
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 415s 943ms/step - accuracy: 0.7416 - loss: 0.6682 - val_accuracy: 0.6770 - val_loss: 0.8782
# Epoch 6/15
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 408s 928ms/step - accuracy: 0.7807 - loss: 0.5742 - val_accuracy: 0.7120 - val_loss: 0.8935
# Epoch 7/15
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 410s 931ms/step - accuracy: 0.8222 - loss: 0.4858 - val_accuracy: 0.7053 - val_loss: 0.9999
# Epoch 8/15
# ...

# %%
model.save("qv_scene_classifier_150111.h5")
print("Model saved as qv_scene_classifier_150111.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as qv_scene_classifier_150111.h5
